# %% [markdown]
# # GW170817: Posterior plot comparison for TaylorF2 with varying PN accuracies

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import bilby
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.lines as mlines
from kde_contour import kdeplot_2d_clevels

size_axis_label = 12
size_tick_label = 10
size_legend_label = 11

# %% [markdown]
# ### Waveforms: TaylorF2-3PN, TaylorF2-3.5PN, TaylorF2-4PN, TaylorF2-4.5PN

# %%
rng = np.random.default_rng(12345)

param_names = ['chirp_mass', 'mass_ratio']

def pick_param(df_, param_names, idx, title):
    """Pick parameters at idx and tag with waveform label."""
    df_ = df_[param_names].iloc[idx].copy()
    df_["templates"] = title
    return df_


result0 = bilby.result.read_in_result("../result_files/TaylorF2_3PN_bayeswave.hdf5").posterior
result1 = bilby.result.read_in_result("../result_files/TaylorF2_3p5PN_bayeswave.hdf5").posterior
result2 = bilby.result.read_in_result("../result_files/TaylorF2_4PN_bayeswave.hdf5").posterior
result3 = bilby.result.read_in_result("../result_files/TaylorF2_4p5PN_bayeswave.hdf5").posterior

# Same posterior indices for all waveforms (fair comparison)
nsamples = min(len(result0), len(result1), len(result2), len(result3))
# nsamples = 3000
idx = rng.choice(nsamples, size=nsamples, replace=False)

result_tf2_3pn = pick_param(result0, param_names, idx, "TF2 3PN")
result_tf2_3p5pn = pick_param(result1, param_names, idx, "TF2 3.5PN")
result_tf2_4pn = pick_param(result2, param_names, idx, "TF2 4PN")
result_tf2_4p5pn = pick_param(result3, param_names, idx, "TF2 4.5PN")

result = pd.concat(
    [result_tf2_3pn, result_tf2_3p5pn, result_tf2_4pn, result_tf2_4p5pn],
    ignore_index=True,
)
# avoid seaborn/pandas FutureWarning from inf values in posteriors
result[param_names] = result[param_names].replace([np.inf, -np.inf], np.nan)
# Out:
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# ...

# %%
# log10BF values
log10BF_3PN = bilby.result.read_in_result("../result_files/TaylorF2_3PN_bayeswave_fmax1024Hz.hdf5").log_10_bayes_factor
log10BF_3p5PN = bilby.result.read_in_result("../result_files/TaylorF2_3p5PN_bayeswave_fmax1024Hz.hdf5").log_10_bayes_factor
log10BF_4PN = bilby.result.read_in_result("../result_files/TaylorF2_4PN_bayeswave.hdf5").log_10_bayes_factor
log10BF_4p5PN = bilby.result.read_in_result("../result_files/TaylorF2_4p5PN_bayeswave.hdf5").log_10_bayes_factor

# print 
print("TF2 3PN:", log10BF_3PN)
print("TF2 3.5PN:", log10BF_3p5PN)
print("TF2 4PN:", log10BF_4PN)
print("TF2 4.5PN:", log10BF_4p5PN)
# Out:
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:22 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

plt.rcParams.update({
    'backend': 'Agg',
    'savefig.dpi': 300,
    'grid.alpha': 0.5,
    'path.simplify': True,
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "font.size": size_tick_label,
    "axes.labelsize": size_axis_label,
    "axes.titlesize": size_axis_label,
    "xtick.labelsize": size_tick_label,
    "ytick.labelsize": size_tick_label,
    "legend.fontsize": size_legend_label,
    "figure.titlesize": size_axis_label,
    'mathtext.fontset': 'custom',
    'xtick.major.size': 6,
    'ytick.major.size': 6,
    'xtick.minor.size': 3,
    'ytick.minor.size': 3,
    'xtick.major.width': 1,
    'ytick.major.width': 1,
    'xtick.minor.width': 1,
    'ytick.minor.width': 1,
    'lines.markeredgewidth': 1,
    'legend.numpoints': 1,
    'legend.frameon': False,
    'legend.handletextpad': 0.3
})

vars = ['chirp_mass', 'mass_ratio']
waveforms = ['TF2 3PN', 'TF2 3.5PN', 'TF2 4PN', 'TF2 4.5PN']
palette = {'TF2 3PN': 'C0', 'TF2 3.5PN': 'C1', 'TF2 4PN': 'C2', 'TF2 4.5PN': 'C3'}

# scatter pairplot + diagonal KDE (your original plot type)
diag_fill_alpha = 0.15
pairplot_scatter = sns.pairplot(
    result,
    vars=vars,
    hue='templates',
    palette=palette,
    corner=True,
    kind='scatter',
    plot_kws=dict(marker='.', alpha=0.0, s=5),
    diag_kind='kde',
    diag_kws={'alpha': diag_fill_alpha, 'linewidth': 0.8,'bw_adjust': 1.0},
)

# overlay KDE contours on lower triangle
# (use kdeplot_2d_clevels: sns.kdeplot breaks on matplotlib 3.8+ with seaborn 0.12)
contour_levels = np.sort([0.864,0.393])
for i, row_var in enumerate(vars):
    for j, col_var in enumerate(vars):
        if i > j:
            ax = pairplot_scatter.axes[i, j]
            for wf, color in zip(waveforms, palette.values()):
                subset = result[result['templates'] == wf]
                kdeplot_2d_clevels(
                    xs=subset[col_var],
                    ys=subset[row_var],
                    levels=contour_levels,
                    ax=ax,
                    color=color,
                    linewidths=0.8,
                    auto_bound=True,
                    bw_method=0.8,   # try this: smaller = tighter contours
                )

if pairplot_scatter._legend is not None:
    pairplot_scatter._legend.remove()

pairplot_scatter.fig.set_size_inches(4, 4)
pairplot_scatter.fig.subplots_adjust(
    left=0.14875, bottom=0.1290625, right=0.96265625, top=0.97625,
    wspace=0.1436, hspace=0.0862,
)

# %%
# --- styling only (match Figure6_1024Hz.ipynb); plot type unchanged above ---
pairplot_scatter.axes[1, 1].tick_params(axis='x', rotation=45, pad=1, labelsize=size_tick_label)
pairplot_scatter.axes[1, 0].tick_params(axis='x', rotation=45, pad=1, labelsize=size_tick_label)
pairplot_scatter.axes[1, 0].tick_params(axis='y', rotation=45, pad=1, labelsize=size_tick_label)

pairplot_scatter.axes[1, 0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.4f' % x))
pairplot_scatter.axes[1, 1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.1f' % x))
pairplot_scatter.axes[1, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.1f' % x))

pairplot_scatter.axes[1, 0].set_xlabel(r'$\mathcal{M}$', labelpad=2, fontsize=size_axis_label)
pairplot_scatter.axes[1, 0].set_xlim(1.19725, 1.19762)
pairplot_scatter.axes[1, 0].set_ylabel(r'$q$', labelpad=4, fontsize=size_axis_label)
pairplot_scatter.axes[1, 0].set_ylim(0.65, 0.99)
pairplot_scatter.axes[1, 1].set_xlabel(r'$q$', labelpad=13, fontsize=size_axis_label)
pairplot_scatter.axes[1, 1].set_xlim(0.65, 0.99)
pairplot_scatter.axes[0, 0].set_xlim(1.19725, 1.19762)

for ax in pairplot_scatter.axes.flat:
    if ax is not None:
        ax.tick_params(axis='both', which='both', labelsize=size_tick_label)
        ax.xaxis.label.set_size(size_axis_label)
        ax.yaxis.label.set_size(size_axis_label)
        ax.title.set_size(size_axis_label)

# add grid
for i in range(2):
    for j in range(2):
        if pairplot_scatter.axes[i, j] is not None:
            pairplot_scatter.axes[i, j].grid(True, which="both", ls="-", alpha=0.5)

blue_line = mlines.Line2D([], [], color='C0', label='TF2 3PN')
orange_line = mlines.Line2D([], [], color='C1', label='TF2 3.5PN')
green_line = mlines.Line2D([], [], color='C2', label='TF2 4PN')
red_line = mlines.Line2D([], [], color='C3', label='TF2 4.5PN')
handles = [blue_line, orange_line, green_line, red_line]
legend_labels = [h.get_label() for h in handles]
legend = pairplot_scatter.fig.legend(handles=handles, labels=legend_labels, bbox_to_anchor=(0., 0.9, 0.9, .0), ncol=1, frameon=True, fontsize=size_legend_label, edgecolor='lightgray')
legend.get_frame().set_boxstyle('Round', pad=0.0, rounding_size=0.2)

pairplot_scatter.fig.savefig("GW170817_TF2.pdf", bbox_inches="tight", dpi=300)
plt.show()
