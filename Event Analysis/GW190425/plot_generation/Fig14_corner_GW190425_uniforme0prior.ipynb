# %% [markdown]
# # Extended corner plot of GW190425 (uniform e0 prior)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import bilby
import pandas as pd
import numpy as np
import matplotlib.lines as mlines
import corner

# %%
# TaylorF2Ecck
result1 = bilby.result.read_in_result("../result_files/TF2Ecck_3PN_T1700406.hdf5")
chirp_mass1 = result1.posterior["chirp_mass"].values
mass_ratio1 =  result1.posterior["mass_ratio"].values
e01 = result1.posterior["eccentricity"].values
theta_jn1 = result1.posterior["theta_jn"].values
D1 = result1.posterior["luminosity_distance"].values
ra1 = result1.posterior["ra"].values
dec1 = result1.posterior["dec"].values
m11 = (chirp_mass1*(1+mass_ratio1)**(1/5))/mass_ratio1**(3/5)
m21 = chirp_mass1*mass_ratio1**(2/5)*(1+mass_ratio1)**(1/5)
mtot1 = m11 + m21
eta1 = (m11*m21)/(mtot1**2)

# TaylorF2Ecc 3PN
result2 = bilby.result.read_in_result("../result_files/TF2Ecc_3PN_T1700406.hdf5")
chirp_mass2 = result2.posterior["chirp_mass"].values
mass_ratio2 =  result2.posterior["mass_ratio"].values
e02 = result2.posterior["eccentricity"].values
theta_jn2 = result2.posterior["theta_jn"].values
D2 = result2.posterior["luminosity_distance"].values
ra2 = result2.posterior["ra"].values
dec2 = result2.posterior["dec"].values
m12 = (chirp_mass2*(1+mass_ratio2)**(1/5))/mass_ratio2**(3/5)
m22 = chirp_mass2*mass_ratio2**(2/5)*(1+mass_ratio2)**(1/5)
mtot2 = m12 + m22
eta2 = (m12*m22)/(mtot2**2)

# TaylorF2Ecc 3.5PN (no spin)
result3 = bilby.result.read_in_result("../result_files/TF2Ecc_3p5PN_T1700406.hdf5")
chirp_mass3 = result3.posterior["chirp_mass"].values
mass_ratio3 =  result3.posterior["mass_ratio"].values
e03 = result3.posterior["eccentricity"].values
theta_jn3 = result3.posterior["theta_jn"].values
D3 = result3.posterior["luminosity_distance"].values
ra3 = result3.posterior["ra"].values
dec3 = result3.posterior["dec"].values
m13 = (chirp_mass3*(1+mass_ratio3)**(1/5))/mass_ratio3**(3/5)
m23 = chirp_mass3*mass_ratio3**(2/5)*(1+mass_ratio3)**(1/5)
mtot3 = m13 + m23
eta3 = (m13*m23)/(mtot3**2)
# Out:
# 06:12 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:12 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 06:12 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data

# %%
# get SNRs
result1.meta_data
# Out:
# {'bilby_pipe_version': '1.8.1',
#  'bilby_version': '2.8.0',
#  'command_line_args': {'accounting': 'ligo.dev.o4.cbc.pe.bilby',
#   'accounting_user': None,
#   'additional_transfer_paths': ['__none__'],
#   'allow_tape': True,
#   'analysis_executable': None,
#   'analysis_executable_parser': None,
#   'calibration_correction_type': None,
#   'calibration_lookup_table': None,
#   'calibration_marginalization': False,
#   'calibration_model': None,
#   'calibration_prior_boundary': 'reflective',
#   'catch_waveform_errors': True,
#   'channel_dict': '{L1:DCS-CALIB_STRAIN_CLEAN_C01_T1700406_v3, V1:Hrec_hoft_16384Hz_T1700406_v3}',
#   'coherence_test': False,
#   'conda_env': None,
#   'condor_job_priority': np.int64(0),
#   'container': None,
#   'conversion_function': None,
#   'cosmology': 'Planck15',
#   'create_summary': False,
#   'data_dict': "{'L1': '/home/hemantakumar.phurailatpam/GW190425/L-L1_HOFT_C01_T1700406_v3-1240211456-4096.gwf',  'V1': '/home/hemantakumar.phurailatpam/GW190425/V-V1Online_T1700406_v3-1240214000-2000.gwf'}",
#   'data_dump_file': None,
#   'data_find_url': None,
#   'data_find_urltype': 'osdf',
#   'data_format': None,
#   'default_prior': 'BBHPriorDict',
#   'deltaT': np.float64(0.2),
#   'desired_sites': None,
#   'detectors': ['L1', 'V1'],
#   'disable_hdf5_locking': False,
#   'distance_marginalization': False,
#   'distance_marginalization_lookup_table': None,
#   'duration': np.float64(160.0),
#   'email': None,
#   'enforce_signal_duration': True,
#   'environment_variables': "{'PYTHONPATH': '/home/hemantakumar.phurailatpam/lalsuite-install/lib/python3.11/site-packages', 'LAL_DATADIR': '/home/hemantakumar.phurailatpam/lalsuite-install/share/lal', 'LALSIMULATION_DATADIR': '/home/hemantakumar.phurailatpam/lalsuite-install/share/lalsimulation', 'LAL_PREFIX': '/home/hemantakumar.phurailatpam/lalsuite-install', 'LALSIMULATION_PREFIX': '/home/hemantakumar.phurailatpam/lalsuite-install'}",
#   'epsilon': np.float64(0.025),
#   'existing_dir': None,
#   'extra_likelihood_kwargs': None,
#   'fetch_open_data_kwargs': None,
#   'fiducial_parameters': None,
#   'final_result': True,
#   'final_result_nsamples': np.int64(20000),
#   'frame_type_dict': None,
#   'frequency_domain_source_model': 'bilby.gw.source.lal_eccentric_binary_black_hole_no_spins',
#   'gaussian_noise': False,
#   'generation_function': None,
#   'generation_pool': 'local-pool',
#   'generation_seed': None,
#   'getenv': ['__none__'],
#   'gps_file': None,
#   'gps_tuple': None,
#   'idx': np.int64(0),
#   'ignore_gwpy_data_quality_check': True,
#   'ini': 'TF2Ecck_3PN_T1700406_config_complete.ini',
#   'injection': False,
#   'injection_dict': None,
#   'injection_file': None,
#   'injection_frequency_domain_source_model': None,
#   'injection_numbers': ['__none__'],
#   'injection_waveform_approximant': None,
#   'injection_waveform_arguments': None,
#   'injection_waveform_generator_constructor_dict': None,
#   'jitter_time': True,
#   'label': 'TF2Ecck_3PN_T1700406_data0_1240215503-017_generation',
#   'likelihood_type': 'GravitationalWaveTransient',
#   'local': False,
#   'local_generation': False,
#   'local_plot': False,
#   'log_directory': None,
#   'maximum_frequency': '512.',
#   'minimum_frequency': '20.',
#   'mode_array': ['__none__'],
#   'n_parallel': np.int64(1),
#   'n_simulation': np.int64(1),
#   'notification': 'Never',
#   'number_of_response_curves': np.int64(1000),
#   'numerical_relativity_file': None,
#   'osg': False,
#   'outdir': 'outdir_TF2Ecck_3PN_T1700406',
#   'overwrite_outdir': False,
#   'periodic_restart_time': np.int64(604800),
#   'phase_marginalization': True,
#   'plot_calibration': False,
#   'plot_corner': False,
#   'plot_data': False,
#   'plot_format': 'png',
#   'plot_injection': False,
#   'plot_marginal': False,
#   'plot_skymap': False,
#   'plot_spectrogram': False,
#   'plot_trace': True,
#   'plot_waveform': False,
#   'pn_amplitude_order': np.int64(0),
#   'pn_phase_order': np.int64(6),
#   'pn_spin_order': np.int64(0),
#   'pn_tidal_order': np.int64(0),
#   'post_trigger_duration': np.float64(1.0),
#   'postprocessing_arguments': None,
#   'postprocessing_executable': None,
#   'prior_dict': "{mass_1 = Constraint(name='mass_1', minimum=1.0,maximum=3.0), mass_2 = Constraint(name='mass_2', minimum=1.0,maximum=3.0), chirp_mass = bilby.gw.prior.UniformInComponentsChirpMass(name='chirp_mass', minimum=1.3,maximum=1.8), mass_ratio = bilby.gw.prior.UniformInComponentsMassRatio(name='mass_ratio', minimum=0.1, maximum=1.), eccentricity = Uniform(name='e0', minimum=0.0, maximum=0.1), luminosity_distance =  PowerLaw(alpha=2, name='luminosity_distance', minimum=10.0, maximum=1000.0, unit='Mpc'), theta_jn = Sine(name='theta_jn'), psi =  Uniform(name='psi', minimum=0, maximum=6.283185307179586), phase = Uniform(name='phase', minimum=0, maximum=6.283185307179586), ra = Uniform(name='ra', minimum=0, maximum=6.283185307179586, boundary='periodic'), dec = Cosine(name='dec'), }",
#   'prior_file': None,
#   'psd_dict': "{'L1': '/home/hemantakumar.phurailatpam/GW190425/TaylorF2-LS_psds_L1.txt', 'V1': '/home/hemantakumar.phurailatpam/GW190425/TaylorF2-LS_psds_V1.txt'}",
#   'psd_fractional_overlap': np.float64(0.5),
#   'psd_length': np.int64(32),
#   'psd_maximum_duration': np.int64(1024),
#   'psd_method': 'median',
#   'psd_start_time': None,
#   'queue': None,
#   'reference_frame': 'sky',
#   'reference_frequency': np.float64(20.0),
#   'request_cpus': np.int64(16),
#   'request_disk': np.float64(2.0),
#   'request_memory': np.float64(8.0),
#   'request_memory_generation': None,
#   'resampling_method': 'lal',
#   'result_format': 'hdf5',
#   'reweight_nested_samples': True,
#   'reweighting_configuration': None,
#   'roq_folder': None,
#   'roq_linear_matrix': None,
#   'roq_quadratic_matrix': None,
#   'roq_scale_factor': np.float64(1.0),
#   'roq_weight_format': 'hdf5',
#   'roq_weights': None,
#   'sampler': 'dynesty',
#   'sampler_kwargs': "{'nlive': 1000, 'naccept': 60, 'check_point_plot': True, 'check_point_delta_t': 1800, 'print_method': 'interval-60', 'sample': 'acceptance-walk', 'walks': 100, 'resume': True, 'npool': 16}",
#   'sampling_frequency': np.float64(2048.0),
#   'sampling_seed': None,
#   'scheduler': 'condor',
#   'scheduler_analysis_time': '14-00:00:00',
#   'scheduler_args': None,
#   'scheduler_env': None,
#   'scheduler_module': ['__none__'],
#   'scitoken_issuer': None,
#   'single_postprocessing_arguments': None,
#   'single_postprocessing_executable': None,
#   'spline_calibration_amplitude_uncertainty_dict': None,
#   'spline_calibration_envelope_dict': None,
#   'spline_calibration_nodes': np.int64(10),
#   'spline_calibration_phase_uncertainty_dict': None,
#   'submit': False,
#   'summarypages_arguments': None,
#   'time_marginalization': True,
#   'time_reference': 'geocent',
#   'timeslide_dict': None,
#   'timeslide_file': None,
#   'transfer_files': True,
#   'trigger_time': '1240215503.017',
#   'tukey_roll_off': np.float64(0.4),
#   'update_fiducial_parameters': False,
#   'verbose': False,
#   'waveform_approximant': 'TaylorF2Ecck',
#   'waveform_arguments_dict': None,
#   'waveform_generator': 'bilby.gw.waveform_generator.WaveformGenerator',
#   'waveform_generator_constructor_dict': None,
#   'webdir': None,
#   'zero_noise': False},
#  'data_dump': 'outdir_TF2Ecck_3PN_T1700406/data/TF2Ecck_3PN_T1700406_data0_1240215503-017_generation_data_dump.pickle',
#  'environment_packages': {'name': ['anyio',
#    'argon2-cffi',
#    'argon2-cffi-bindings',
#    'arrow',
#    'astropy',
#    'astropy-iers-data',
#    'asttokens',
#    'async-lru',
#    'attrs',
#    'babel',
#    'backports.zstd',
#    'bcrypt',
#    'beautifulsoup4',
#    'bilby',
#    'bilby.cython',
#    'bilby_pipe',
#    'bleach',
#    'Brotli',
#    'cached-property',
#    'certifi',
#    'cffi',
#    'charset-normalizer',
#    'click',
#    'comm',
#    'ConfigArgParse',
#    'contourpy',
#    'corner',
#    'cryptography',
#    'cycler',
#    'dateparser',
#    'debugpy',
#    'decorator',
#    'defusedxml',
#    'dill',
#    'dqsegdb2',
#    'dynesty',
#    'emcee',
#    'exceptiongroup',
#    'executing',
#    'fastjsonschema',
#    'fonttools',
#    'fqdn',
#    'future',
#    'gssapi',
#    'gwdatafind',
#    'gwosc',
#    'gwpy',
#    'h11',
#    'h2',
#    'h5py',
#    'hpack',
#    'htgettoken',
#    'httpcore',
#    'httpx',
#    'hyperframe',
#    'idna',
#    'igwn-auth-utils',
#    'igwn-ligolw',
#    'igwn-segments',
#    'importlib_metadata',
#    'invoke',
#    'ipykernel',
#    'ipython',
#    'ipython_pygments_lexers',
#    'isoduration',
#    'jedi',
#    'Jinja2',
#    'joblib',
#    'json5',
#    'jsonpointer',
#    'jsonschema',
#    'jsonschema-specifications',
#    'jupyter_client',
#    'jupyter_core',
#    'jupyter-events',
#    'jupyter-lsp',
#    'jupyter_server',
#    'jupyter_server_terminals',
#    'jupyterlab',
#    'jupyterlab_pygments',
#    'jupyterlab_server',
#    'kiwisolver',
#    'lalsuite',
#    'lark',
#    'ligo-gracedb',
#    'ligotimegps',
#    'lscsoft-glue',
#    'MarkupSafe',
#    'matplotlib',
#    'matplotlib-inline',
#    'mistune',
#    'munkres',
#    'narwhals',
#    'nbclient',
#    'nbconvert',
#    'nbformat',
#    'nest_asyncio',
#    'notebook_shim',
#    'numpy',
#    'overrides',
#    'packaging',
#    'pandas',
#    'pandocfilters',
#    'paramiko',
#    'parso',
#    'pesummary',
#    'pexpect',
#    'pillow',
#    'pip',
#    'platformdirs',
#    'plotly',
#    'prometheus_client',
#    'prompt_toolkit',
#    'psutil',
#    'ptyprocess',
#    'pure_eval',
#    'PyCondor',
#    'pycparser',
#    'pyerfa',
#    'pyFFTW',
#    'Pygments',
#    'PyJWT',
#    'PyNaCl',
#    'pyparsing',
#    'PySocks',
#    'python-dateutil',
#    'python-json-logger',
#    'pytz',
#    'PyYAML',
#    'pyzmq',
#    'referencing',
#    'regex',
#    'requests',
#    'rfc3339_validator',
#    'rfc3986-validator',
#    'rfc3987-syntax',
#    'rpds-py',
#    'safe-netrc',
#    'scikit-learn',
#    'scipy',
#    'scitokens',
#    'seaborn',
#    'Send2Trash',
#    'setuptools',
#    'six',
#    'sniffio',
#    'soupsieve',
#    'stack_data',
#    'tenacity',
#    'terminado',
#    'threadpoolctl',
#    'tinycss2',
#    'tomli',
#    'tornado',
#    'tqdm',
#    'traitlets',
#    'typing_extensions',
#    'typing_utils',
#    'tzdata',
#    'tzlocal',
#    'unicodedata2',
#    'uri-template',
#    'urllib3',
#    'wcwidth',
#    'webcolors',
#    'webencodings',
#    'websocket-client',
#    'wheel',
#    'zipp'],
#   'version': ['4.13.0',
#    '25.1.0',
#    '25.1.0',
#    '1.4.0',
#    '7.2.0',
#    '0.2026.5.11.1.8.52',
#    '3.0.1',
#    '2.3.0',
#    '26.1.0',
#    '2.18.0',
#    '1.5.0',
#    '5.0.0',
#    '4.14.3',
#    '2.8.0',
#    '0.5.4',
#    '1.8.1',
#    '6.3.0',
#    '1.2.0',
#    '1.5.2',
#    '2026.4.22',
#    '2.0.0',
#    '3.4.7',
#    '8.3.3',
#    '0.2.3',
#    '1.7.5',
#    '1.3.3',
#    '2.2.3',
#    '48.0.0',
#    '0.12.1',
#    '1.4.0',
#    '1.8.20',
#    '5.2.1',
#    '0.7.1',
#    '0.4.1',
#    '1.3.0',
#    '3.0.0',
#    '3.1.6',
#    '1.3.1',
#    '2.2.1',
#    '2.21.2',
#    '4.62.1',
#    '1.5.1',
#    '1.0.0',
#    '1.11.1',
#    '2.1.1',
#    '0.8.2',
#    '4.0.1',
#    '0.16.0',
#    '4.3.0',
#    '3.16.0',
#    '4.1.0',
#    '2.6',
#    '1.0.9',
#    '0.28.1',
#    '6.1.0',
#    '3.13',
#    '1.4.0',
#    '2.1.1',
#    '2.1.1',
#    '8.8.0',
#    '3.0.3',
#    '7.2.0',
#    '9.13.0',
#    '1.1.1',
#    '20.11.0',
#    '0.19.2',
#    '3.1.6',
#    '1.5.3',
#    '0.14.0',
#    '3.1.1',
#    '4.26.0',
#    '2025.9.1',
#    '8.8.0',
#    '5.9.1',
#    '0.12.1',
#    '2.3.1',
#    '2.18.2',
#    '0.5.4',
#    '4.5.7',
#    '0.3.0',
#    '2.28.0',
#    '1.5.0',
#    '7.26.11',
#    '1.3.1',
#    '2.15.7',
#    '2.1.0',
#    '4.1.1',
#    '3.0.3',
#    '3.10.9',
#    '0.2.2',
#    '3.2.1',
#    '1.1.4',
#    '2.21.0',
#    '0.10.4',
#    '7.17.1',
#    '5.10.4',
#    '1.6.0',
#    '0.2.4',
#    '1.26.4',
#    '7.7.0',
#    '26.0',
#    '3.0.3',
#    '1.5.0',
#    '5.0.0',
#    '0.8.7',
#    '1.6.3',
#    '4.9.0',
#    '12.2.0',
#    '26.0.1',
#    '4.9.6',
#    '6.7.0',
#    '0.25.0',
#    '3.0.52',
#    '7.2.2',
#    '0.7.0',
#    '0.2.3',
#    '0.6.1',
#    '3.0',
#    '2.0.1.5',
#    '0.15.1',
#    '2.20.0',
#    '2.12.1',
#    '1.6.2',
#    '3.3.2',
#    '1.7.1',
#    '2.9.0.post0',
#    '3.2.1',
#    '2026.2',
#    '6.0.3',
#    '27.1.0',
#    '0.37.0',
#    '2026.5.9',
#    '2.34.1',
#    '0.1.4',
#    '0.1.1',
#    '1.1.0',
#    '0.30.0',
#    '1.0.1',
#    '1.8.0',
#    '1.17.1',
#    '1.9.7',
#    '0.13.2',
#    '2.1.0',
#    '82.0.1',
#    '1.17.0',
#    '1.3.1',
#    '2.8.3',
#    '0.6.3',
#    '9.1.4',
#    '0.18.1',
#    '3.6.0',
#    '1.4.0',
#    '2.4.1',
#    '6.5.5',
#    '4.67.3',
#    '5.15.0',
#    '4.15.0',
#    '0.1.0',
#    '2026.2',
#    '5.3.1',
#    '17.0.1',
#    '1.3.0',
#    '2.7.0',
#    '0.7.0',
#    '25.10.0',
#    '0.5.1',
#    '1.9.0',
#    '0.46.3',
#    '3.23.1']},
#  'injection_parameters': None,
#  'likelihood': {'calibration_marginalization': False,
#   'distance_marginalization': False,
#   'duration': np.float64(160.0),
#   'frequency_domain_source_model': <function bilby.gw.source.lal_eccentric_binary_black_hole_no_spins(frequency_array, mass_1, mass_2, eccentricity, luminosity_distance, theta_jn, phase, **kwargs)>,
#   'interferometers': {'L1': {'name': 'L1'}, 'V1': {'name': 'V1'}},
#   'lal_version': 'lal_version=7.7.1.1, lal_git_version=Branch: master;Tag: None;Id: 4be7b9e5027dabaded1c0f2d24a0c41170d97587;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed',
#   'lalsimulation_version': 'lalsimulation_version=6.2.1.1, lalsimulation_git_version=Branch: master;Tag: None;Id: 4be7b9e5027dabaded1c0f2d24a0c41170d97587;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed',
#   'parameter_conversion': <function bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters(parameters)>,
#   'phase_marginalization': True,
#   'reference_frame': 'sky',
#   'sampling_frequency': np.float64(2048.0),
#   'start_time': np.float64(1240215344.0169678),
#   'time_domain_source_model': None,
#   'time_marginalization': True,
#   'time_reference': 'geocent',
#   'waveform_arguments': {'catch_waveform_errors': True,
#    'maximum_frequency': np.float64(512.0),
#    'minimum_frequency': np.float64(20.0),
#    'mode_array': None,
#    'pn_amplitude_order': np.int64(0),
#    'pn_phase_order': np.int64(6),
#    'pn_spin_order': np.int64(0),
#    'pn_tidal_order': np.int64(0),
#    'reference_frequency': np.float64(20.0),
#    'waveform_approximant': 'TaylorF2Ecck'},
#   'waveform_generator_class': bilby.gw.waveform_generator.WaveformGenerator},
#  'loaded_modules': {'astropy': '7.2.0',
#   'astropy_iers_data': '0.2026.5.11.1.8.52',
#   'bilby': '2.8.0',
#   'bilby_cython': '0.5.4',
#   'bilby_pipe': '1.8.1',
#   'brotli': '1.2.0',
#   'certifi': '2026.4.22',
#   'charset_normalizer': '3.4.7',
#   'configargparse': '1.7.5',
#   'cycler': '0.12.1',
#   'defusedxml': '0.7.1',
#   'gwosc': '0.8.2',
#   'idna': '3.13',
#   'jinja2': '3.1.6',
#   'kiwisolver': '1.5.0',
#   'markupsafe': '3.0.3',
#   'matplotlib': '3.10.9',
#   'numpy': '1.26.4',
#   'packaging': '26.0',
#   'pandas': '3.0.3',
#   'pycondor': '0.6.1',
#   'pyparsing': '3.3.2',
#   'pytz': '2026.2',
#   'requests': '2.34.1',
#   'scipy': '1.17.1',
#   'six': '1.17.0',
#   'tenacity': '9.1.4',
#   'tornado': '6.5.5',
#   'urllib3': '2.7.0'},
#  'reweighting_configuration': None,
#  'run_statistics': {'ncores': np.int64(16),
#   'neffsamples': np.int64(7221),
#   'nlikelihood': np.int64(17900914),
#   'sampling_time_s': np.int64(75725)},
#  'unknown_command_line_args': ['--online-pe', 'False']}

# %%
sigma = 100-90
mean1, median1, std1, upper_90percentile1, lower_90percentile1 = np.mean(e01), np.median(e01), np.std(e01), np.percentile(e01, 100-sigma/2), np.percentile(e01, sigma/2)
mean2, median2, std2, upper_90percentile2, lower_90percentile2 = np.mean(e02), np.median(e02), np.std(e02), np.percentile(e02, 100-sigma/2), np.percentile(e02, sigma/2)
mean3, median3, std3, upper_90percentile3, lower_90percentile3 = np.mean(e03), np.median(e03), np.std(e03), np.percentile(e03, 100-sigma/2), np.percentile(e03, sigma/2)
print(f"TaylorF2Ecck3PN: mean={mean1:.4f}, median={median1:.4f}, upper_90percentile={upper_90percentile1:.4f}, lower_90percentile={lower_90percentile1:.4f}")
print(f"TaylorF2Ecc3PN: mean={mean2:.4f}, median={median2:.4f}, upper_90percentile={upper_90percentile2:.4f}, lower_90percentile={lower_90percentile2:.4f}")
print(f"TaylorF2Ecc3p5PN: mean={mean3:.4f}, median={median3:.4f}, upper_90percentile={upper_90percentile3:.4f}, lower_90percentile={lower_90percentile3:.4f}")
# Out:
# TaylorF2Ecck3PN: mean=0.0110, median=0.0101, upper_90percentile=0.0233, lower_90percentile=0.0011
# TaylorF2Ecc3PN: mean=0.0112, median=0.0105, upper_90percentile=0.0240, lower_90percentile=0.0011
# TaylorF2Ecc3p5PN: mean=0.0116, median=0.0113, upper_90percentile=0.0234, lower_90percentile=0.0013

# %%
print(f"TaylorF2Ecck3PN e0: {median1:.3f}^+{upper_90percentile1-median1:.3f}_-{median1-lower_90percentile1:.3f}")
print(f"TaylorF2Ecc3PN e0: {median2:.3f}^+{upper_90percentile2-median2:.3f}_-{median2-lower_90percentile2:.3f}")
print(f"TaylorF2Ecc3p5PN e0: {median3:.3f}^+{upper_90percentile3-median3:.3f}_-{median3-lower_90percentile3:.3f}")
# Out:
# TaylorF2Ecck3PN e0: 0.010^+0.013_-0.009
# TaylorF2Ecc3PN e0: 0.010^+0.013_-0.009
# TaylorF2Ecc3p5PN e0: 0.011^+0.012_-0.010

# %%
# log10BF values
log10BF1 = result1.log_10_bayes_factor
log10BF2 = result2.log_10_bayes_factor
log10BF3 = result3.log_10_bayes_factor
print(f"TaylorF2Ecck3PN log10BF: {log10BF1:.2f}")
print(f"TaylorF2Ecc3PN log10BF: {log10BF2:.2f}")
print(f"TaylorF2Ecc3p5PN log10BF: {log10BF3:.2f}")
# Out:
# TaylorF2Ecck3PN log10BF: 21.50
# TaylorF2Ecc3PN log10BF: 21.36
# TaylorF2Ecc3p5PN log10BF: 21.33

# %%
rng = np.random.default_rng(12345)
nsamples = np.min([len(chirp_mass1), len(chirp_mass2), len(chirp_mass3)])
data1 = np.transpose(np.array([chirp_mass1, mass_ratio1, mtot1, eta1, e01, D1, theta_jn1]))
df1 = pd.DataFrame(data1, columns=["chirp_mass", "mass_ratio", 'mtot', 'eta', "eccentricity", "luminosity_distance", "theta_jn"])
df1 = df1.sample(n=nsamples, random_state=rng)

data2 = np.transpose(np.array([chirp_mass2, mass_ratio2, mtot2, eta2, e02, D2, theta_jn2]))
df2 = pd.DataFrame(data2, columns=["chirp_mass", "mass_ratio", 'mtot', 'eta', "eccentricity", "luminosity_distance", "theta_jn"])
df2 = df2.sample(n=nsamples, random_state=rng)

data3 = np.transpose(np.array([chirp_mass3, mass_ratio3, mtot3, eta3, e03, D3, theta_jn3]))
df3 = pd.DataFrame(data3, columns=["chirp_mass", "mass_ratio", 'mtot', 'eta', "eccentricity", "luminosity_distance", "theta_jn"])
df3 = df3.sample(n=nsamples, random_state=rng)

# %%
ndim = 7
size_axis_label = 17
size_tick_label = 15
size_legend_label = 16

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "font.size": size_tick_label,
    "axes.labelsize": size_axis_label,
    "axes.titlesize": size_axis_label,
    "xtick.labelsize": size_tick_label,
    "ytick.labelsize": size_tick_label,
    "legend.fontsize": size_legend_label,
    "figure.titlesize": size_axis_label
})
fig, axes = plt.subplots(ndim, ndim, figsize=(14, 14), gridspec_kw={"hspace": 0.1, "wspace": 0.1})

# Generate corner plots with adjusted label padding
corner.corner(df1, fig=fig,color = 'C0', bins=25, smooth=0.8, plot_datapoints=False, plot_density=False, contourf_kwargs= dict(alpha=0.4), levels=(0.393,0.864), hist_kwargs={'linewidth': 1}, contour_kwargs={'linewidths': 1}, show_titles=True, quantiles=(0.05, 0.5, 0.95), title_fmt='.4f', title_kwargs={'fontsize': size_legend_label}, label_kwargs={'fontsize': size_axis_label})

corner.corner(df2, fig=fig, color='C1', bins=25, smooth=0.8, plot_datapoints=False, plot_density=False, contourf_kwargs= dict(alpha=0.4), levels=(0.393,0.864), hist_kwargs={'linewidth': 1}, contour_kwargs={'linewidths': 1},)

corner.corner(df3, fig=fig, color='C2', bins=25, smooth=0.8, plot_datapoints=False, plot_density=False, contourf_kwargs= dict(alpha=0.4), levels=(0.393,0.864), hist_kwargs={'linewidth': 1}, contour_kwargs={'linewidths': 1})

# x-axis tick labels
# Mc
axes[6, 0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.4f' % x))
min_, max_ = 1.48450, 1.48718
axes[6,0].set_xlim(min_, max_)
axes[5,0].set_xlim(min_, max_)
axes[4,0].set_xlim(min_, max_)
axes[3,0].set_xlim(min_, max_)
axes[2,0].set_xlim(min_, max_)
axes[1,0].set_xlim(min_, max_)
axes[0,0].set_xlim(min_, max_)
# q
axes[6, 1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.3f' % x))
min_, max_ = 0.500, 0.99
axes[6,1].set_xlim(min_, max_)
axes[5,1].set_xlim(min_, max_)
axes[4,1].set_xlim(min_, max_)
axes[3,1].set_xlim(min_, max_)
axes[2,1].set_xlim(min_, max_)
axes[1,1].set_xlim(min_, max_)
# m
axes[6, 2].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.3f' % x))
min_, max_ = 3.413, 3.55
axes[6,2].set_xlim(min_, max_)
axes[5,2].set_xlim(min_, max_)
axes[4,2].set_xlim(min_, max_)
axes[3,2].set_xlim(min_, max_)
axes[2,2].set_xlim(min_, max_)
# eta
axes[6, 3].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.3f' % x))
min_, max_ = 0.234, 0.250
axes[6,3].set_xlim(min_, max_)
axes[5,3].set_xlim(min_, max_)
axes[4,3].set_xlim(min_, max_)
axes[3,3].set_xlim(min_, max_)
axes[3,3].set_xlim(min_, max_)
# e0
axes[6, 4].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.3f' % x))
min_, max_ = 0.001, 0.05
axes[6,4].set_xlim(min_, max_)
axes[5,4].set_xlim(min_, max_)
axes[4,4].set_xlim(min_, max_)
# DL
axes[6, 5].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.2f' % x))
min_, max_ = 35, 265
axes[6,5].set_xlim(min_, max_)
axes[5,5].set_xlim(min_, max_)
# theta_jn
axes[6, 6].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '%.3f' % x))
min_, max_ = 0.0, np.pi
axes[6,6].set_xlim(min_, max_)

# y-axis tick labels
# theta_jn
axes[6, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.3f' % y))
min_, max_ = 0.0, np.pi
axes[6,0].set_ylim(min_, max_)
axes[6,1].set_ylim(min_, max_)
axes[6,2].set_ylim(min_, max_)
axes[6,3].set_ylim(min_, max_)
axes[6,4].set_ylim(min_, max_)
axes[6,5].set_ylim(min_, max_)
# DL
axes[5, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.2f' % y))
min_, max_ = 35, 265
axes[5,0].set_ylim(min_, max_)
axes[5,1].set_ylim(min_, max_)
axes[5,2].set_ylim(min_, max_)
axes[5,3].set_ylim(min_, max_)
axes[5,4].set_ylim(min_, max_)
# e0
axes[4, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.3f' % y))
min_, max_ = 0.001, 0.039
axes[4,0].set_ylim(min_, max_)
axes[4,1].set_ylim(min_, max_)
axes[4,2].set_ylim(min_, max_)
axes[4,3].set_ylim(min_, max_)
# eta
axes[3, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.3f' % y))
min_, max_ = 0.234, 0.250
axes[3,0].set_ylim(min_, max_)
axes[3,1].set_ylim(min_, max_)
axes[3,2].set_ylim(min_, max_)
# m
axes[2, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.3f' % y))
min_, max_ = 3.413, 3.55
axes[2,0].set_ylim(min_, max_)
axes[2,1].set_ylim(min_, max_)
# q
axes[1, 0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '%.3f' % y))
min_, max_ = 0.500, 0.99
axes[1,0].set_ylim(min_, max_)

def inner_ticks(limits, n=3):
    return np.linspace(limits[0], limits[1], n + 2)[1:-1]

for i in range(ndim):
    for j in range(ndim):
        if j > i:
            axes[i, j].axis('off')
            continue
        axes[i, j].set_xticks(inner_ticks(axes[i, j].get_xlim()))
        if i > j:
            axes[i, j].set_yticks(inner_ticks(axes[i, j].get_ylim()))
        axes[i, j].tick_params(axis='both', which='both', labelsize=size_tick_label)

# x-axis labels
axes[6,0].set_xlabel(r'$\mathcal{M}$', labelpad=2, fontsize=size_axis_label)
axes[6,1].set_xlabel(r'$q$', labelpad=11, fontsize=size_axis_label)
axes[6,2].set_xlabel(r'$m$', labelpad=11, fontsize=size_axis_label)
axes[6,3].set_xlabel(r'$\eta$', labelpad=11, fontsize=size_axis_label)
axes[6,4].set_xlabel(r'$e_0$', labelpad=11, fontsize=size_axis_label)
axes[6,5].set_xlabel(r'$D_L$', labelpad=11, fontsize=size_axis_label)
axes[6,6].set_xlabel(r'$\theta_{jn}$', labelpad=11, fontsize=size_axis_label)
# y-axis labels
axes[6, 0].set_ylabel(r'$\theta_{jn}$', labelpad=11, fontsize=size_axis_label)
axes[5, 0].set_ylabel(r'$D_L$', labelpad=11, fontsize=size_axis_label)
axes[4, 0].set_ylabel(r'$e_0$', labelpad=11, fontsize=size_axis_label)
axes[3, 0].set_ylabel(r'$\eta$', labelpad=11, fontsize=size_axis_label)
axes[2, 0].set_ylabel(r'$m$', labelpad=11, fontsize=size_axis_label)
axes[1, 0].set_ylabel(r'$q$', labelpad=11, fontsize=size_axis_label)

# add grid
for i in range(ndim):
    for j in range(ndim):
        if axes[i, j] is not None and j <= i:
            axes[i, j].tick_params(axis='both', which='both', labelsize=size_tick_label)
            axes[i, j].xaxis.label.set_size(size_axis_label)
            axes[i, j].yaxis.label.set_size(size_axis_label)
            axes[i, j].grid(True, which="both", ls="-", alpha=0.5)

# add legend with line colors
blue_line = mlines.Line2D([], [], color='C0', label='Ecck 3PN')
orange_line = mlines.Line2D([], [], color='C1', label='Ecc 3PN')
green_line = mlines.Line2D([], [], color='C2', label='Ecc 3.5PN')
handles = [blue_line, orange_line, green_line]
labels = [h.get_label() for h in handles] 
# legend = fig.legend(handles=handles, labels=labels, bbox_to_anchor=(0., 0.9, 0.9, .0), ncol=1, fontsize=size_legend_label, frameon=True, edgecolor='lightgray')
# # # rounded box for legend
# legend.get_frame().set_boxstyle('Round', pad=0.0, rounding_size=0.2)
legend = fig.legend(handles=handles, labels=labels, handlelength=2, loc='upper right', bbox_to_anchor=(0., 0.9, 0.9, .0), frameon=True, fontsize=size_legend_label, edgecolor='lightgray')
# # rounded box for legend
legend.get_frame().set_boxstyle('Round', pad=0.0, rounding_size=0.2)
# Modify line width for legend entries
for handle in legend.get_lines():
    handle.set_linewidth(2)
    handle.set_alpha(0.8)

plt.savefig("fullpe_gw190425.pdf", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## TaylorF2

# %%
import bilby
import pandas as pd
import numpy as np

log10BF4 = bilby.result.read_in_result("../result_files/TF2Ecck_3PN_T1700406.hdf5").log_10_bayes_factor
print(f"TaylorF2 3PN log10BF: {log10BF4:.2f}")
# Out:
# 06:12 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# TaylorF2 3PN log10BF: 21.50
